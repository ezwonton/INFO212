# %% [markdown]
# <h1 style="text-align:center"> Drexel University </h1>
# <h2 style = "text-align:center"> College of Computing and Informatics</h2>
# <h2 style = "text-align:center">INFO 212: Data Science Programming I</h2>
# <h3 style = "text-align:center">Assignment 3</h3>
# <div style="text-align:center; border-style:solid; padding: 10px">
# <div style="font-weight:bold">Due Date: Sunday, May 13, 2018</div>
# This assignment counts for 15% of the final grade
# </div>
#
# <h3 style="color:red; font-weight:bold; text-decoration: underline">DON'T FORGET TO PUT YOUR NAME BELOW</h3>
#
# ### NAME:
#
#
# ### A. Assignment Overview
# This assignment provides the opportunity for you to practice with the capabilities of handling with external data in Python.
#
# ### B. What to Hand In
#
# Sumbit a completed this Jupyter notebook.
#
# ### C. How to Hand In
#
# Submit your Jupyter notebook file through the course website in the Blackboard Learn system.
#
# ### D. When to Hand In
#
# 1. Submit your assignment no later than 11:59pm in the due date.
# 2. There will be a 10% (absolute value) deduction for each day of lateness, to a maximum of 3 days; assignments will not be accepted beyond that point. Missing work will earn a zero grade.
#
# ### E. Written Presentation Requirements (if applicable)
# Images must be clear and legible. Assignments will be judged on the basis of visual appearance, grammatical correctness, and quality of writing, as well as their contents. Please make sure that the text of your assignments is well-structured, using paragraphs, full sentences, and other features of well-written presentation. Text font size should be either 11 or 12 points.
#
# ### F. Marking Schemes:
#
# Marking assignments will be based on several aspects: presentation, correctness and coding styles.
#
# For programming questions, 10% of the mark will be judged on the coding style.
#
# The following is a set of guidelines for the coding style in this course:
# 1. Write a good comment for each variable, each method, each control branch, and each loop.
# 2. Use appropriate indentations to indicate control flows and blocks of code.
# 3. Your method comments must mention the purpose of each parameter, and must be grammatically correct.
# 4. Each line must be less than 80 characters long including tabs and spaces.
# 5. Put a blank space before and after every operator.
# 6. When breaking up a long line, break it before an operator, not after.
#
# ### G. Data Sets
#
# This assignment needs the data sets specified in the questions.
#
# ### H. Answer the following questions

# %% [markdown]
# #### Question 1:
#
# Wikipedia has a Webpage: (https://en.wikipedia.org/wiki/List_of_countries_by_past_and_future_population): *List of countries by past and future population*. On this page, there are three tables containing the estimated populations from 1950 to 2050 for all the countries. Read the description on the Webpage to understand the information in the tables. Follow the instructions below at each step and answer the questions to complete this question:
# - Download the Webpage as an HTML file in your disk.
# - Read in the tables using Pandas' `read_html` method. Answer the following question:
#  * How many tables have you read in?
# - Show the first 5 rows of the DataFrame correpsonding to the table "Estimates between the years 1950 and 1980 (in thousands)"
# - How many countries does the Wikipedia page list their populations?
# - Create a DataFrame containing all the data from the population tables. I.e., the DataFrame contains the popultation and average annual growth data from 1950-2050. You need to combine the three population tables.
# - For the top 10 most populous countries at 1950, plot their population data from 1950-2050 (in 5-year interval). The plot should use years 1950-2050 as x axis, and population numbers as y axis. The following figure shows the expected result.
# ![](assignment3-question1-population.png)
# - For the same top 10 most populous contries at 1950, plot the average annual growth for each previous five-year period starting from 1955 to 2050 in 5-year interval. The following figure shows the expected result.
# ![](assignment3-question1-aag.png)

# %%
import pandas as pd
# Write your code below
tables = pd.read_html("datasets/List-population.html")

# %%
len(tables)
# Out:
# 4

# %%
tables[0].head()
# Out:
#   Country (or dependent territory)  1950  1955     %   1960   %.1   1965  \
# 0                      Afghanistan  8151  8892  1.76   9830  2.03  10998
# 1                          Albania  1228  1393  2.56   1624  3.12   1884
# 2                          Algeria  8893  9842  2.05  10910  2.08  11964
# 3                   American Samoa    20    20  0.72     21  0.20     25
# 4                          Andorra     7     7  0.04      9  6.28     14
#
#      %.2   1970   %.3   1975   %.4   1980   %.5
# 0   2.27  12431  2.48  14133  2.60  15045  1.26
# 1   3.02   2157  2.74   2402  2.17   2672  2.16
# 2   1.86  13932  3.09  16141  2.99  18807  3.10
# 3   4.23     28  2.08     30  1.68     33  1.81
# 4  10.17     20  7.49     27  6.32     34  4.81

# %%
tables[0].columns = ['Country (or dependent territory)', '1950', '1955', '1955AAG', 
                     '1960', '1960AAG', '1965', '1965AAG', '1970', '1970AAG', \
                     '1975', '1975AAG', '1980', '1980AAG']

# %%
tables[0].head()
# Out:
#   Country (or dependent territory)  1950  1955  1955AAG   1960  1960AAG  \
# 0                      Afghanistan  8151  8892     1.76   9830     2.03
# 1                          Albania  1228  1393     2.56   1624     3.12
# 2                          Algeria  8893  9842     2.05  10910     2.08
# 3                   American Samoa    20    20     0.72     21     0.20
# 4                          Andorra     7     7     0.04      9     6.28
#
#     1965  1965AAG   1970  1970AAG   1975  1975AAG   1980  1980AAG
# 0  10998     2.27  12431     2.48  14133     2.60  15045     1.26
# 1   1884     3.02   2157     2.74   2402     2.17   2672     2.16
# 2  11964     1.86  13932     3.09  16141     2.99  18807     3.10
# 3     25     4.23     28     2.08     30     1.68     33     1.81
# 4     14    10.17     20     7.49     27     6.32     34     4.81

# %%
len(tables[0])
# Out:
# 228

# %%
tables[1].columns
# Out:
# Index(['Country (or dependent territory)', '1985', '%', '1990', '%.1', '1995',
#        '%.2', '2000', '%.3', '2005', '%.4', '2010', '%.5', '2015', '%.6'],
#       dtype='object')

# %%
tables[1].columns = ['Country (or dependent territory)', '1985', '1985AAG', '1990', 
                     '1990AAG', '1995', '1995AAG', '2000', '2000AAG', '2005', 
                     '2005AAG', '2010', '2010AAG', '2015', '2015AAG']

# %%
tables[1].head()
# Out:
#   Country (or dependent territory)   1985  1985AAG   1990  1990AAG   1995  \
# 0                      Afghanistan  13120    -2.70  13569     0.67  19446
# 1                          Albania   2957     2.05   3245     1.88   3159
# 2                          Algeria  22009     3.19  25191     2.74  28322
# 3                   American Samoa     39     3.57     48     4.09     54
# 4                          Andorra     45     5.84     53     3.41     64
#
#    1995AAG   2000  2000AAG   2005  2005AAG   2010  2010AAG   2015  2015AAG
# 0     7.46  22462     2.93  26335     3.23  29121     2.03  32565     2.26
# 1    -0.54   3159     0.00   3025    -0.86   2987    -0.25   3030     0.28
# 2     2.37  30639     1.58  32918     1.45  35950     1.78  39543     1.92
# 3     2.69     58     1.39     57    -0.28     56    -0.53     55    -0.41
# 4     3.70     66     0.58     77     3.18     85     2.12     86     0.25

# %%
tables[2].columns
# Out:
# Index(['Country (or dependent territory)', '2020', '%', '2025', '%.1', '2030',
#        '%.2', '2035', '%.3', '2040', '%.4', '2045', '%.5', '2050', '%.6'],
#       dtype='object')

# %%
tables[2].columns = ['Country (or dependent territory)', '2020', '2020AAG', '2025', 
                     '2025AAG', '2030', '2030AAG', '2035', '2035AAG', '2040', 
                     '2040AAG', '2045', '2045AAG', '2050', '2050AAG']

# %%
tables[2].head()
# Out:
#   Country (or dependent territory)   2020  2020AAG   2025  2025AAG   2030  \
# 0                      Afghanistan  36644     2.39  41118     2.33  45665
# 1                          Albania   3075     0.30   3105     0.20   3103
# 2                          Algeria  42973     1.68  45842     1.30  48149
# 3                   American Samoa     54    -0.21     54    -0.17     53
# 4                          Andorra     86     0.01     86    -0.12     85
#
#    2030AAG   2035  2035AAG   2040  2040AAG   2045  2045AAG   2050  2050AAG
# 0     2.12  50195     1.91  54717     1.74  59256     1.61  63796     1.49
# 1    -0.01   3063    -0.26   2994    -0.45   2913    -0.55   2825    -0.61
# 2     0.99  50118     0.80  52030     0.75  53894     0.71  55445     0.57
# 3    -0.32     52    -0.45     51    -0.45     50    -0.29     50    -0.06
# 4    -0.21     83    -0.30     82    -0.46     79    -0.69     75    -0.93

# %%
df = pd.concat([tables[0], tables[1].iloc[:, 1:], tables[2].iloc[:, 1:]], axis = 1)

# %%
df.shape
# Out:
# (228, 42)

# %%
df.columns
# Out:
# Index(['Country (or dependent territory)', '1950', '1955', '1955AAG', '1960',
#        '1960AAG', '1965', '1965AAG', '1970', '1970AAG', '1975', '1975AAG',
#        '1980', '1980AAG', '1985', '1985AAG', '1990', '1990AAG', '1995',
#        '1995AAG', '2000', '2000AAG', '2005', '2005AAG', '2010', '2010AAG',
#        '2015', '2015AAG', '2020', '2020AAG', '2025', '2025AAG', '2030',
#        '2030AAG', '2035', '2035AAG', '2040', '2040AAG', '2045', '2045AAG',
#        '2050', '2050AAG'],
#       dtype='object')

# %%
df.head()
# Out:
#   Country (or dependent territory)  1950  1955  1955AAG   1960  1960AAG  \
# 0                      Afghanistan  8151  8892     1.76   9830     2.03
# 1                          Albania  1228  1393     2.56   1624     3.12
# 2                          Algeria  8893  9842     2.05  10910     2.08
# 3                   American Samoa    20    20     0.72     21     0.20
# 4                          Andorra     7     7     0.04      9     6.28
#
#     1965  1965AAG   1970  1970AAG   ...      2030  2030AAG   2035  2035AAG  \
# 0  10998     2.27  12431     2.48   ...     45665     2.12  50195     1.91
# 1   1884     3.02   2157     2.74   ...      3103    -0.01   3063    -0.26
# 2  11964     1.86  13932     3.09   ...     48149     0.99  50118     0.80
# 3     25     4.23     28     2.08   ...        53    -0.32     52    -0.45
# 4     14    10.17     20     7.49   ...        85    -0.21     83    -0.30
#
#     2040  2040AAG   2045  2045AAG   2050  2050AAG
# 0  54717     1.74  59256     1.61  63796     1.49
# 1   2994    -0.45   2913    -0.55   2825    -0.61
# 2  52030     0.75  53894     0.71  55445     0.57
# 3     51    -0.45     50    -0.29     50    -0.06
# 4     82    -0.46     79    -0.69     75    -0.93
#
# [5 rows x 42 columns]

# %%
top_10 = df.iloc[list(df['1950'].sort_values(ascending = False)[1:11].index)]

# %%
top_10
# Out:
#     Country (or dependent territory)    1950    1955  1955AAG    1960  \
# 41                             China  562580  607047     1.53  651340
# 89                             India  369881  404268     1.79  445394
# 215                    United States  151869  165070     1.68  179980
# 164                           Russia  101937  111126     1.74  119632
# 99                             Japan   83806   89816     1.39   94092
# 90                         Indonesia   82979   90255     1.70  100146
# 72                           Germany   68375   70196     0.53   72481
# 27                            Brazil   53444   61652     2.90   71412
# 214                   United Kingdom   50128   50947     0.32   52373
# 96                             Italy   47106   48634     0.64   50198
#
#      1960AAG    1965  1965AAG    1970  1970AAG   ...        2030  2030AAG  \
# 41      1.42  716667     1.93  822116     2.78   ...     1403894    -0.04
# 89      1.96  494964     2.13  553889     2.28   ...     1460744     0.91
# 215     1.74  193527     1.46  203985     1.06   ...      359403     0.69
# 164     1.49  126542     1.13  130246     0.58   ...      138215    -0.28
# 99      0.93   98883     1.00  104345     1.08   ...      120752    -0.43
# 90      2.10  110754     2.03  122292     2.00   ...      296450     1.60
# 72      0.64   75639     0.86   77784     0.56   ...       78022    -0.31
# 27      2.98   82602     2.95   94931     2.82   ...      228720     0.51
# 214     0.55   54351     0.74   55633     0.47   ...       68451     0.36
# 96      0.64   51988     0.70   53662     0.64   ...       62623     0.01
#
#         2035  2035AAG     2040  2040AAG     2045  2045AAG     2050  2050AAG
# 41   1388258    -0.22  1364680    -0.34  1335915    -0.43  1301628    -0.52
# 89   1519491     0.79  1571716     0.68  1617238     0.57  1656554     0.48
# 215   370339     0.60   380220     0.53   389395     0.48   398329     0.45
# 164   136313    -0.28   134496    -0.27   132432    -0.31   129909    -0.38
# 99    117747    -0.50   114449    -0.57   110907    -0.63   107210    -0.68
# 90    305653     1.47   314085     1.33   321524     1.24   327282     0.91
# 72     76590    -0.37    74984    -0.42    73277    -0.46    71542    -0.48
# 27    233068     0.39   236077     0.27   237826     0.18   238390     0.11
# 214    69394     0.27    70149     0.22    70743     0.17    71154     0.12
# 96     62531    -0.03    62319    -0.07    61957    -0.12    61416    -0.18
#
# [10 rows x 42 columns]

# %%
countries = list(top_10['Country (or dependent territory)'])

# %%
countries
# Out:
# ['China',
#  'India',
#  'United States',
#  'Russia',
#  'Japan',
#  'Indonesia',
#  'Germany',
#  'Brazil',
#  'United Kingdom',
#  'Italy']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
top_10 = top_10[['Country (or dependent territory)', '1950', '1955', '1960',
       '1965',  '1970',  '1975', 
       '1980', '1985',  '1990',  '1995',
        '2000', '2005',  '2010', 
       '2015',  '2020',  '2025', '2030',
        '2035',  '2040',  '2045', 
       '2050']]

# %%
top_10.head()
# Out:
#     Country (or dependent territory)    1950    1955    1960    1965    1970  \
# 41                             China  562580  607047  651340  716667  822116
# 89                             India  369881  404268  445394  494964  553889
# 215                    United States  151869  165070  179980  193527  203985
# 164                           Russia  101937  111126  119632  126542  130246
# 99                             Japan   83806   89816   94092   98883  104345
#
#        1975    1980     1985     1990   ...        2005     2010     2015  \
# 41   920295  987822  1061876  1153164   ...     1302285  1336681  1367486
# 89   618923  684888   759613   838159   ...     1090974  1173109  1251696
# 215  215466  227225   237924   249623   ...      295517   309348   321369
# 164  134294  139039   143938   147973   ...      143320   142527   142424
# 99   111574  116808   120755   123538   ...      127716   127580   126920
#
#         2020     2025     2030     2035     2040     2045     2050
# 41   1394016  1407007  1403894  1388258  1364680  1335915  1301628
# 89   1326094  1396047  1460744  1519491  1571716  1617238  1656554
# 215   334504   347335   359403   370339   380220   389395   398329
# 164   141723   140140   138215   136313   134496   132432   129909
# 99    125508   123386   120752   117747   114449   110907   107210
#
# [5 rows x 22 columns]

# %%
top_10.set_index('Country (or dependent territory)', inplace = True)

# %%
top_10 = top_10.T

# %%
top_10.head()
# Out:
# Country (or dependent territory)   China   India  United States  Russia  \
# 1950                              562580  369881         151869  101937
# 1955                              607047  404268         165070  111126
# 1960                              651340  445394         179980  119632
# 1965                              716667  494964         193527  126542
# 1970                              822116  553889         203985  130246
#
# Country (or dependent territory)   Japan  Indonesia  Germany  Brazil  \
# 1950                               83806      82979    68375   53444
# 1955                               89816      90255    70196   61652
# 1960                               94092     100146    72481   71412
# 1965                               98883     110754    75639   82602
# 1970                              104345     122292    77784   94931
#
# Country (or dependent territory)  United Kingdom  Italy
# 1950                                       50128  47106
# 1955                                       50947  48634
# 1960                                       52373  50198
# 1965                                       54351  51988
# 1970                                       55633  53662

# %%
years= top_10.index

# %%
ax  = top_10.\
plot.line(figsize=(12, 8), marker = 'o')
ax.set_xticks(range(22))
ax.set_xticklabels(years, rotation = 45)
ax.set_xlabel('Year')
ax.set_ylabel('Population in Thousands')
ax.legend(loc='best')

# %%
top_10.columns
# Out:
# Index(['Country (or dependent territory)', '1950', '1955', '1955AAG', '1960',
#        '1960AAG', '1965', '1965AAG', '1970', '1970AAG', '1975', '1975AAG',
#        '1980', '1980AAG', '1985', '1985AAG', '1990', '1990AAG', '1995',
#        '1995AAG', '2000', '2000AAG', '2005', '2005AAG', '2010', '2010AAG',
#        '2015', '2015AAG', '2020', '2020AAG', '2025', '2025AAG', '2030',
#        '2030AAG', '2035', '2035AAG', '2040', '2040AAG', '2045', '2045AAG',
#        '2050', '2050AAG'],
#       dtype='object')

# %%
top_10_aag = top_10[['Country (or dependent territory)', '1955AAG',
       '1960AAG', '1965AAG', '1970AAG',  '1975AAG',
        '1980AAG', '1985AAG', '1990AAG', 
       '1995AAG', '2000AAG',  '2005AAG', '2010AAG',
        '2015AAG',  '2020AAG',  '2025AAG', 
       '2030AAG',  '2035AAG',  '2040AAG',  '2045AAG',
        '2050AAG']]

# %%
top_10_aag.set_index('Country (or dependent territory)', inplace = True)

# %%
top_10_aag = top_10_aag.T

# %%
top_10_aag.head()
# Out:
# Country (or dependent territory)  China  India  United States  Russia  Japan  \
# 1955AAG                            1.53   1.79           1.68    1.74   1.39
# 1960AAG                            1.42   1.96           1.74    1.49   0.93
# 1965AAG                            1.93   2.13           1.46    1.13   1.00
# 1970AAG                            2.78   2.28           1.06    0.58   1.08
# 1975AAG                            2.28   2.25           1.10    0.61   1.35
#
# Country (or dependent territory)  Indonesia  Germany  Brazil  United Kingdom  \
# 1955AAG                                1.70     0.53    2.90            0.32
# 1960AAG                                2.10     0.64    2.98            0.55
# 1965AAG                                2.03     0.86    2.95            0.74
# 1970AAG                                2.00     0.56    2.82            0.47
# 1975AAG                                2.03     0.23    2.49            0.21
#
# Country (or dependent territory)  Italy
# 1955AAG                            0.64
# 1960AAG                            0.64
# 1965AAG                            0.70
# 1970AAG                            0.64
# 1975AAG                            0.70

# %%
ax  = top_10_aag.plot.line(figsize=(12, 8), marker = 'o')
ax.set_xticks(range(22))
ax.set_xticklabels(years[1:], rotation = 45)
ax.set_xlabel('Year')
ax.set_ylabel('Average Annual Growth in Previous 5 Years (%)')
ax.legend(loc='best')

# %% [markdown]
# #### Question 2:
# The file `nobelprize-laureate.json` is a JSON file containing the information about Nobel Prize laureates. Create a Pandas DataFrame from the JSON file and complete the following steps:
# - Answer the question: How many countries does this data set represent as the Nobel Prize laureates's birth countries?
# - Plot the top-20 birth countries in a bar chart showing the country names and the number of laureats born in the countries.
# ![](assignment3-question2-bornCountries-bar.png)
# - Plot a bar chart showing the numbers of countries where the laureates were born since 1901.
# ![](assignment3-question2-bornCountry-change.png)

# %%
# Write your code below
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import json
laureate_json = json.load(open("datasets/nobelprize-laureate.json"))

# %%
laureate_json['laureates'][0]
# Out:
# {'born': '1845-03-27',
#  'bornCity': 'Lennep (now Remscheid)',
#  'bornCountry': 'Prussia (now Germany)',
#  'bornCountryCode': 'DE',
#  'died': '1923-02-10',
#  'diedCity': 'Munich',
#  'diedCountry': 'Germany',
#  'diedCountryCode': 'DE',
#  'firstname': 'Wilhelm Conrad',
#  'gender': 'male',
#  'id': '1',
#  'prizes': [{'affiliations': [{'city': 'Munich',
#      'country': 'Germany',
#      'name': 'Munich University'}],
#    'category': 'physics',
#    'motivation': '"in recognition of the extraordinary services he has rendered by the discovery of the remarkable rays subsequently named after him"',
#    'share': '1',
#    'year': '1901'}],
#  'surname': 'Röntgen'}

# %%
 laureate_df = pd.DataFrame(laureate_json['laureates'])

# %%
laureate_df.shape
# Out:
# (922, 13)

# %%
laureate_json = json.load(open("datasets/nobelprize-laureate.json"))
laureate_df = pd.DataFrame(laureate_json['laureates'])
prize_df = pd.DataFrame([rec['prizes'][0] for rec in laureate_json['laureates']])
laureate_year_df = pd.concat([laureate_df, prize_df], axis = 1)

# %%
prize_df.shape
# Out:
# (922, 6)

# %%
laureate_year_df = pd.concat([laureate_df, prize_df], axis = 1)

# %%
laureate_year_df.head()
# Out:
#          born                bornCity            bornCountry bornCountryCode  \
# 0  1845-03-27  Lennep (now Remscheid)  Prussia (now Germany)              DE
# 1  1853-07-18                  Arnhem        the Netherlands              NL
# 2  1865-05-25              Zonnemaire        the Netherlands              NL
# 3  1852-12-15                   Paris                 France              FR
# 4  1859-05-15                   Paris                 France              FR
#
#          died   diedCity      diedCountry diedCountryCode       firstname  \
# 0  1923-02-10     Munich          Germany              DE  Wilhelm Conrad
# 1  1928-02-04        NaN  the Netherlands              NL  Hendrik Antoon
# 2  1943-10-09  Amsterdam  the Netherlands              NL          Pieter
# 3  1908-08-25        NaN           France              FR   Antoine Henri
# 4  1906-04-19      Paris           France              FR          Pierre
#
#   gender id                                             prizes    surname  \
# 0   male  1  [{'year': '1901', 'category': 'physics', 'shar...    Röntgen
# 1   male  2  [{'year': '1902', 'category': 'physics', 'shar...    Lorentz
# 2   male  3  [{'year': '1902', 'category': 'physics', 'shar...     Zeeman
# 3   male  4  [{'year': '1903', 'category': 'physics', 'shar...  Becquerel
# 4   male  5  [{'year': '1903', 'category': 'physics', 'shar...      Curie
#
#                                         affiliations category  \
# 0  [{'name': 'Munich University', 'city': 'Munich...  physics
# 1  [{'name': 'Leiden University', 'city': 'Leiden...  physics
# 2  [{'name': 'Amsterdam University', 'city': 'Ams...  physics
# 3  [{'name': 'École Polytechnique', 'city': 'Pari...  physics
# 4  [{'name': 'École municipale de physique et de ...  physics
#
#                                           motivation overallMotivation share  \
# 0  "in recognition of the extraordinary services ...               NaN     1
# 1  "in recognition of the extraordinary service t...               NaN     2
# 2  "in recognition of the extraordinary service t...               NaN     2
# 3  "in recognition of the extraordinary services ...               NaN     2
# 4  "in recognition of the extraordinary services ...               NaN     4
#
#    year
# 0  1901
# 1  1902
# 2  1902
# 3  1903
# 4  1903

# %%
countries = laureate_year_df['bornCountry']

# %%
len(countries.unique())
# Out:
# 122

# %%
import numpy as np
ax  = countries.value_counts()[:20].plot.bar(figsize=(12, 8))
ax.set_yticks(np.arange(0, 300, 10))
ax.grid()

# %%
x = laureate_year_df['year'].sort_values().unique()

# %%
len(x)
# Out:
# 115

# %%
y = []
for year in x:
    year_df = laureate_year_df[laureate_year_df['year'] == year]
    y.append(len(year_df['bornCountry'].unique()))

# %%
len(y)
# Out:
# 115

# %%
xtic = [ year for i, year in enumerate(x) if (i + 5) % 5 == 0]
xtic
# Out:
# ['1901',
#  '1906',
#  '1911',
#  '1916',
#  '1921',
#  '1926',
#  '1931',
#  '1936',
#  '1944',
#  '1949',
#  '1954',
#  '1959',
#  '1964',
#  '1969',
#  '1974',
#  '1979',
#  '1984',
#  '1989',
#  '1994',
#  '1999',
#  '2004',
#  '2009',
#  '2014']

# %%
# ?ax.set_xticklabels

# %%
import matplotlib
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(12, 9)
ax.bar(x, y)
ax.set_xticks(ax.get_xticks()[::5])
ax.set_xticklabels(xtic, rotation = 30)
ax.set_title("The Changes of the Number of Laureates' Birth Countries")
ax.set_xlabel("Year")
ax.set_ylabel("Number of Different Countries")
# Out:
# Text(0,0.5,'Number of Different Countries')
