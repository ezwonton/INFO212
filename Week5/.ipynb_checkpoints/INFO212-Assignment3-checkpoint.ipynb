# %% [markdown]
# <h1 style="text-align:center"> Drexel University </h1>
# <h2 style = "text-align:center"> College of Computing and Informatics</h2>
# <h2 style = "text-align:center">INFO 212: Data Science Programming I</h2>
# <h3 style = "text-align:center">Assignment 3</h3>
# <div style="text-align:center; border-style:solid; padding: 10px">
# <div style="font-weight:bold">Due Date: Sunday, May 13, 2018</div>
# This assignment counts for 15% of the final grade
# </div>
#
# <h3 style="color:red; font-weight:bold; text-decoration: underline">DON'T FORGET TO PUT YOUR NAME BELOW</h3>
#
# ### NAME: Eric Wan
#
#
# ### A. Assignment Overview
# This assignment provides the opportunity for you to practice with the capabilities of handling with external data in Python.
#
# ### B. What to Hand In
#
# Sumbit a completed this Jupyter notebook.
#
# ### C. How to Hand In
#
# Submit your Jupyter notebook file through the course website in the Blackboard Learn system.
#
# ### D. When to Hand In
#
# 1. Submit your assignment no later than 11:59pm in the due date.
# 2. There will be a 10% (absolute value) deduction for each day of lateness, to a maximum of 3 days; assignments will not be accepted beyond that point. Missing work will earn a zero grade.
#
# ### E. Written Presentation Requirements (if applicable)
# Images must be clear and legible. Assignments will be judged on the basis of visual appearance, grammatical correctness, and quality of writing, as well as their contents. Please make sure that the text of your assignments is well-structured, using paragraphs, full sentences, and other features of well-written presentation. Text font size should be either 11 or 12 points.
#
# ### F. Marking Schemes:
#
# Marking assignments will be based on several aspects: presentation, correctness and coding styles.
#
# For programming questions, 10% of the mark will be judged on the coding style.
#
# The following is a set of guidelines for the coding style in this course:
# 1. Write a good comment for each variable, each method, each control branch, and each loop.
# 2. Use appropriate indentations to indicate control flows and blocks of code.
# 3. Your method comments must mention the purpose of each parameter, and must be grammatically correct.
# 4. Each line must be less than 80 characters long including tabs and spaces.
# 5. Put a blank space before and after every operator.
# 6. When breaking up a long line, break it before an operator, not after.
#
# ### G. Data Sets
#
# This assignment needs the data sets specified in the questions.
#
# ### H. Answer the following questions

# %% [markdown]
# #### Question 1:
#
# Wikipedia has a Webpage: (https://en.wikipedia.org/wiki/List_of_countries_by_past_and_future_population): *List of countries by past and future population*. On this page, there are three tables containing the estimated populations from 1950 to 2050 for all the countries. Read the description on the Webpage to understand the information in the tables. Follow the instructions below at each step and answer the questions to complete this question:
# - Download the Webpage as an HTML file in your disk.
# - Read in the tables using Pandas' `read_html` method. Answer the following question:
#  * How many tables have you read in?
# - Show the first 5 rows of the DataFrame correpsonding to the table "Estimates between the years 1950 and 1980 (in thousands)"
# - How many countries does the Wikipedia page list their populations?
# - Create a DataFrame containing all the data from the population tables. I.e., the DataFrame contains the popultation and average annual growth data from 1950-2050. You need to combine the three population tables.
# - For the top 10 most populous countries at 1950, plot their population data from 1950-2050 (in 5-year interval). The plot should use years 1950-2050 as x axis, and population numbers as y axis. The following figure shows the expected result.
# ![](assignment3-question1-population.png)
# - For the same top 10 most populous contries at 1950, plot the average annual growth for each previous five-year period starting from 1955 to 2050 in 5-year interval. The following figure shows the expected result.
# ![](assignment3-question1-aag.png)

# %%
import pandas as pd
# importing pandas

df = pd.read_html("List_of_countries_by_past_and_future_population.html", header = 0, index_col = 0)
# reading the html file

# %%
print("There are %s tables read in." %len(df))
# print statement counting the number of dataframes read in
# Out:
# There are 4 tables read in.

# %%
df[0][0:6]
# getting the first 6 rows of the 1950-1980 dataframe
# Out:
#                                   1950  1955     %   1960   %.1   1965    %.2  \
# Country (or dependent territory)
# Afghanistan                       8151  8892  1.76   9830  2.03  10998   2.27
# Albania                           1228  1393  2.56   1624  3.12   1884   3.02
# Algeria                           8893  9842  2.05  10910  2.08  11964   1.86
# American Samoa                      20    20  0.72     21  0.20     25   4.23
# Andorra                              7     7  0.04      9  6.28     14  10.17
# Angola                            4118  4424  1.44   4798  1.64   5135   1.37
#
#                                    1970   %.3   1975   %.4   1980   %.5
# Country (or dependent territory)
# Afghanistan                       12431  2.48  14133  2.60  15045  1.26
# Albania                            2157  2.74   2402  2.17   2672  2.16
# Algeria                           13932  3.09  16141  2.99  18807  3.10
# American Samoa                       28  2.08     30  1.68     33  1.81
# Andorra                              20  7.49     27  6.32     34  4.81
# Angola                             5606  1.77   6051  1.54   7206  3.56

# %%
print("There are %s countries." %(int(df[0].index.nunique())-1))
# counting unique countries and subtracting out "World"
# Out:
# There are 227 countries.

# %%
df_new = pd.concat([df[0], df[1], df[2]], axis=1)
# concatinating a new dataframe from all 3 read in and the not reading in the bottom part, df[3], of the wikipedia page
df_new
# Out:
#                                      1950     1955      %     1960    %.1  \
# Country (or dependent territory)
# Afghanistan                          8151     8892   1.76     9830   2.03
# Albania                              1228     1393   2.56     1624   3.12
# Algeria                              8893     9842   2.05    10910   2.08
# American Samoa                         20       20   0.72       21   0.20
# Andorra                                 7        7   0.04        9   6.28
# Angola                               4118     4424   1.44     4798   1.64
# Anguilla                                6        6   0.80        6   0.79
# Antigua and Barbuda                    46       52   2.19       55   1.32
# Argentina                           17151    18928   1.99    20617   1.72
# Armenia                              1356     1566   2.92     1869   3.61
# Aruba                                  50       54   1.62       58   1.21
# Australia                            8268     9278   2.33    10362   2.24
# Austria                              6936     6947   0.03     7048   0.29
# Azerbaijan                           2886     3314   2.81     3882   3.21
# Bahamas                                71       88   4.33      113   5.19
# Bahrain                               115      131   2.55      157   3.76
# Bangladesh                          45646    49589   1.67    54593   1.94
# Barbados                              211      228   1.53      233   0.44
# Belarus                              7723     7781   0.15     8168   0.98
# Belgium                              8640     8869   0.52     9119   0.56
# Belize                                 66       77   3.17       92   3.62
# Benin                                1673     1847   1.99     2056   2.17
# Bermuda                                39       42   1.30       45   1.36
# Bhutan                                164      187   2.61      213   2.63
# Bolivia                              2767     3075   2.14     3435   2.24
# Bosnia and Herzegovina               2663     2975   2.24     3241   1.73
# Botswana                              431      462   1.39      497   1.50
# Brazil                              53444    61652   2.90    71412   2.98
# British Virgin Islands                  7        7   1.13        8   2.26
# Brunei                                 45       61   6.28       84   6.37
# ...                                   ...      ...    ...      ...    ...
# Brazil                            ...    228720  0.51   233068  0.39   236077
# British Virgin Islands            ...        46  1.80       49  1.60       53
# Brunei                            ...       532  1.28      562  1.11      590
# ...                               ...       ...   ...      ...   ...      ...
# Taiwan                            ...     23508 -0.11    23149 -0.31    22550
# Tajikistan                        ...     10104  1.22    10668  1.09    11203
# Tanzania                          ...     76071  2.60    85946  2.47    96400
# Thailand                          ...     69751  0.05    69447 -0.09    68696
# Gambia                            ...      2555  1.51     2731  1.34     2900
# Togo                              ...     10953  2.37    12246  2.26    13622
# Tonga                             ...       103 -0.47       99 -0.71       94
# Trinidad and Tobago               ...      1152 -0.55     1118 -0.60     1086
# Tunisia                           ...     12087  0.40    12223  0.22    12285
# Turkey                            ...     86671  0.50    88279  0.37    89283
# Turkmenistan                      ...      6027  0.77     6210  0.60     6364
# Turks and Caicos Islands          ...        67  1.61       72  1.43       76
# Tuvalu                            ...        13  0.68       13  0.54       13
# Uganda                            ...     58489  2.90    66782  2.69    75460
# Ukraine                           ...     41699 -0.56    40538 -0.56    39428
# United Arab Emirates              ...      7484  1.16     7773  0.76     7949
# United Kingdom                    ...     68451  0.36    69394  0.27    70149
# United States                     ...    359403  0.69   370339  0.60   380220
# United States Virgin Islands      ...        91 -1.07       86 -1.25       80
# Uruguay                           ...      3467  0.20     3486  0.11     3501
# Uzbekistan                        ...     32855  0.64    33653  0.48    34279
# Vanuatu                           ...       348  1.46      372  1.31      394
# Venezuela                         ...     34958  1.04    36544  0.89    37942
# Vietnam                           ...    105478  0.58   107843  0.44   109602
# Wallis and Futuna                 ...        17  0.08       17 -0.06       16
# Western Sahara                    ...       822  2.23      909  2.04      998
# Yemen                             ...     35660  1.67    38437  1.51    41142
# Zambia                            ...     23137  2.85    26546  2.79    30339
# Zimbabwe                          ...     18820  1.62    20282  1.51    21840
# World                             ...   8340607  0.82  8646305  0.72  8925950
#
#                                    %.4     2045   %.5     2050   %.6
# Country (or dependent territory)
# Afghanistan                       1.74    59256  1.61    63796  1.49
# Albania                          -0.45     2913 -0.55     2825 -0.61
# Algeria                           0.75    53894  0.71    55445  0.57
# American Samoa                   -0.45       50 -0.29       50 -0.06
# Andorra                          -0.46       79 -0.69       75 -0.93
# Angola                            2.34    41280  2.24    45889  2.14
# Anguilla                          1.24       26  1.09       27  0.96
# Antigua and Barbuda               0.65      121  0.52      123  0.41
# Argentina                         0.51    52663  0.42    53512  0.32
# Armenia                          -0.71     2590 -0.82     2469 -0.95
# Aruba                             0.69      147  0.61      151  0.55
# Australia                         0.57    28390  0.49    29013  0.44
# Austria                           0.03     9129 -0.01     9108 -0.05
# Azerbaijan                        0.26    11201  0.15    11210  0.02
# Bahamas                           0.23      372  0.12      372  0.01
# Bahrain                           0.67     1806  0.54     1848  0.45
# Bangladesh                        0.66   199442  0.45   201249  0.17
# Barbados                         -0.22      289 -0.34      283 -0.44
# Belarus                          -0.43     8567 -0.46     8340 -0.53
# Belgium                           0.23    12695  0.18    12773  0.12
# Belize                            1.11      521  0.98      544  0.87
# Benin                             1.96    20425  1.78    22119  1.61
# Bermuda                          -0.19       72 -0.33       70 -0.43
# Bhutan                            0.59      935  0.49      952  0.37
# Bolivia                           1.00    15401  0.88    16004  0.77
# Bosnia and Herzegovina           -0.68     3362 -0.79     3217 -0.88
# Botswana                          0.65     2780  0.65     2872  0.65
# Brazil                            0.27   237826  0.18   238390  0.11
# British Virgin Islands            1.44       57  1.32       60  1.23
# Brunei                            0.96      615  0.85      639  0.76
# ...                                ...      ...   ...      ...   ...
# Taiwan                           -0.52    21759 -0.71    20835 -0.86
# Tajikistan                        0.98    11697  0.87    12133  0.73
# Tanzania                          2.32   107301  2.17   118587  2.02
# Thailand                         -0.22    67546 -0.34    66064 -0.44
# Gambia                            1.21     3060  1.08     3211  0.97
# Togo                              2.15    15074  2.05    16584  1.93
# Tonga                            -1.03       88 -1.44       79 -1.93
# Trinidad and Tobago              -0.58     1055 -0.58     1024 -0.59
# Tunisia                           0.10    12277 -0.01    12181 -0.16
# Turkey                            0.23    89626  0.08    89291 -0.07
# Turkmenistan                      0.49     6498  0.42     6608  0.34
# Turks and Caicos Islands          1.28       81  1.13       85  0.95
# Tuvalu                            0.47       14  0.44       14  0.42
# Uganda                            2.47    84402  2.27    93477  2.06
# Ukraine                          -0.55    38325 -0.57    37149 -0.62
# United Arab Emirates              0.45     8025  0.19     8019 -0.01
# United Kingdom                    0.22    70743  0.17    71154  0.12
# United States                     0.53   389395  0.48   398329  0.45
# United States Virgin Islands     -1.37       75 -1.44       69 -1.43
# Uruguay                           0.09     3504  0.02     3496 -0.05
# Uzbekistan                        0.37    34768  0.28    35117  0.20
# Vanuatu                           1.17      415  1.02      433  0.88
# Venezuela                         0.75    39174  0.64    40256  0.55
# Vietnam                           0.32   110718  0.20   111174  0.08
# Wallis and Futuna                -0.15       16 -0.19       16 -0.22
# Western Sahara                    1.87     1086  1.71     1174  1.57
# Yemen                             1.37    43710  1.22    46081  1.06
# Zambia                            2.71    34497  2.60    38993  2.48
# Zimbabwe                          1.49    23492  1.47    25199  1.41
# World                             0.64  9180226  0.56  9408142  0.49
#
# [228 rows x 41 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
# importing libraries

top11 = df_new.nlargest(11, columns = "1950")
# grabs the top 11 largest values in the 1950s column

years = list(df_new)[0:2] + list(df_new)[3::2]
# makes a list of the different years from the columns of the dataframe

top11_years = top11[years]
# grabs the top 11 largest countries by year

top10 = top11_years.iloc[1:]
# Getting the top 11 values as the fist is world

plot = top10.T.plot(figsize=(20,20), grid = True, title="Top10 Population Change (%)")
# transposes the top 10 countries so that years are along the x axis

plot.set_xlabel("Year")
plot.set_ylabel("Population")
# labels the axes
# Out:
# Text(0,0.5,'Population')

# %%
import matplotlib.pyplot as plt
import numpy as np
# importing the libraries

top11 = df_new.nlargest(11, columns = "1950")
# grabs the top 11 largest values in the 1950s column

top11_change = top11.iloc[:, 2::2]
# grabs the % change columns of the dataframe

top10 = top11_change.iloc[1:]
# removes the first row "World"

plot = top10.T.plot(figsize=(20,20), grid = True, title="Top10 Population (Thousands)")
# transposes the top 10 countries so that years are along the x axis

plot.set_xlabel("Year")
plot.set_ylabel("Population Change")
# sets axes
# Out:
# Text(0,0.5,'Population Change')

# %% [markdown]
# #### Question 2:
# The file `nobelprize-laureate.json` is a JSON file containing the information about Nobel Prize laureates. Create a Pandas DataFrame from the JSON file and complete the following steps:
# - Answer the question: How many countries does this data set represent as the Nobel Prize laureates's birth countries?
# - Plot the top-20 birth countries in a bar chart showing the country names and the number of laureats born in the countries.
# ![](assignment3-question2-bornCountries-bar.png)
# - Plot a bar chart showing the numbers of countries where the laureates were born since 1901.
# ![](assignment3-question2-bornCountry-change.png)

# %%
df = pd.read_json("nobelprice-laureate.json", orient = "columns")
# reads the json file

df_L = pd.read_json((df["laureates"]).to_json(), orient = "index")
# reads the "laureates" column of the json file

df_L
# the dataframe
# Out:
#            born                bornCity                          bornCountry  \
# 0    1845-03-27  Lennep (now Remscheid)                Prussia (now Germany)
# 1    1853-07-18                  Arnhem                      the Netherlands
# 10   1845-08-16               Hollerich                           Luxembourg
# 100  1926-07-09             Chicago, IL                                  USA
# 101  1917-12-09             Council, ID                                  USA
# 102  1931-03-22            Brooklyn, NY                                  USA
# 103  1936-01-27           Ann Arbor, MI                                  USA
# 104  1923-12-13        Indianapolis, IN                                  USA
# 105  1905-09-30                   Leeds                       United Kingdom
# 106  1899-03-13          Middletown, CT                                  USA
# 107  1894-07-09              Kronshtadt          Russian Empire (now Russia)
# 108  1933-04-26                  Munich                              Germany
# 109  1936-01-10             Houston, TX                                  USA
# 11   1874-04-25                 Bologna                                Italy
# 110  1932-12-05            New York, NY                                  USA
# 111  1926-01-29     Jhang Maghi&#257;na                 India (now Pakistan)
# 112  1933-05-03            New York, NY                                  USA
# 113  1931-09-29             Chicago, IL                                  USA
# 114  1923-03-10            Merriman, NE                                  USA
# 115  1920-03-11               Dordrecht                      the Netherlands
# 116  1921-05-05         Mount Verno, NY                                  USA
# 117  1918-04-20                    Lund                               Sweden
# 118  1936-06-08             Waltham, MA                                  USA
# 119  1910-10-19                  Lahore                 India (now Pakistan)
# 12   1850-06-06                   Fulda           Hesse-Kassel (now Germany)
# 120  1911-08-09          Pittsburgh, PA                                  USA
# 121  1934-03-31                 Gorizia                                Italy
# 122  1925-11-24               the Hague                      the Netherlands
# 123  1943-06-28                 Schroda  German-occupied Poland (now Poland)
# 124  1906-12-25              Heidelberg                              Germany
# ..          ...                     ...                                  ...
# 901  1951-09-14                  London                       United Kingdom
# 902  1943-06-22                Aberdeen                       United Kingdom
# 903  1944-10-21                   Paris                               France
# 904  1942-05-24               Edinburgh                       United Kingdom
# 905  1951-05-18       Barger-Compascuum                      the Netherlands
# 906  1951-08-10                  Bogotá                             Colombia
# 907  1948-10-09                  London                       United Kingdom
# 908  1949-04-18                Helsinki                              Finland
# 97               GB                                         Sir Martin   male
# 98              NaN                                             Antony   male
# 99               DK                                         Aage Niels   male
#
#       id                                             prizes        surname
# 0      1  [{'year': '1901', 'category': 'physics', 'shar...        Röntgen
# 1      2  [{'year': '1902', 'category': 'physics', 'shar...        Lorentz
# 10    12  [{'year': '1908', 'category': 'physics', 'shar...       Lippmann
# 100  103  [{'year': '1975', 'category': 'physics', 'shar...      Mottelson
# 101  104  [{'year': '1975', 'category': 'physics', 'shar...      Rainwater
# 102  105  [{'year': '1976', 'category': 'physics', 'shar...        Richter
# 103  106  [{'year': '1976', 'category': 'physics', 'shar...           Ting
# 104  107  [{'year': '1977', 'category': 'physics', 'shar...       Anderson
# 105  108  [{'year': '1977', 'category': 'physics', 'shar...           Mott
# 106  109  [{'year': '1977', 'category': 'physics', 'shar...      van Vleck
# 107  110  [{'year': '1978', 'category': 'physics', 'shar...        Kapitsa
# 108  111  [{'year': '1978', 'category': 'physics', 'shar...        Penzias
# 109  112  [{'year': '1978', 'category': 'physics', 'shar...         Wilson
# 11    13  [{'year': '1909', 'category': 'physics', 'shar...        Marconi
# 110  113  [{'year': '1979', 'category': 'physics', 'shar...        Glashow
# 111  114  [{'year': '1979', 'category': 'physics', 'shar...          Salam
# 112  115  [{'year': '1979', 'category': 'physics', 'shar...       Weinberg
# 113  116  [{'year': '1980', 'category': 'physics', 'shar...         Cronin
# 114  117  [{'year': '1980', 'category': 'physics', 'shar...          Fitch
# 115  118  [{'year': '1981', 'category': 'physics', 'shar...    Bloembergen
# 116  119  [{'year': '1981', 'category': 'physics', 'shar...       Schawlow
# 117  120  [{'year': '1981', 'category': 'physics', 'shar...       Siegbahn
# 118  121  [{'year': '1982', 'category': 'physics', 'shar...         Wilson
# 119  122  [{'year': '1983', 'category': 'physics', 'shar...  Chandrasekhar
# 12    14  [{'year': '1909', 'category': 'physics', 'shar...          Braun
# 120  123  [{'year': '1983', 'category': 'physics', 'shar...         Fowler
# 121  124  [{'year': '1984', 'category': 'physics', 'shar...         Rubbia
# 122  125  [{'year': '1984', 'category': 'physics', 'shar...   van der Meer
# 123  126  [{'year': '1985', 'category': 'physics', 'shar...   von Klitzing
# 124  127  [{'year': '1986', 'category': 'physics', 'shar...          Ruska
# ..   ...                                                ...            ...
# 901  929  [{'year': '2016', 'category': 'physics', 'shar...        Haldane
# 902  930  [{'year': '2016', 'category': 'physics', 'shar...     Kosterlitz
# 903  931  [{'year': '2016', 'category': 'chemistry', 'sh...        Sauvage
# 904  932  [{'year': '2016', 'category': 'chemistry', 'sh...       Stoddart
# 905  933  [{'year': '2016', 'category': 'chemistry', 'sh...        Feringa
# 906  934  [{'year': '2016', 'category': 'peace', 'share'...         Santos
# 907  935  [{'year': '2016', 'category': 'economics', 'sh...           Hart
# 908  936  [{'year': '2016', 'category': 'economics', 'sh...      Holmström
# 909  937  [{'year': '2016', 'category': 'literature', 's...          Dylan
# 91    93  [{'year': '1971', 'category': 'physics', 'shar...          Gabor
# 910  938  [{'year': '2017', 'category': 'medicine', 'sha...           Hall
# 911  939  [{'year': '2017', 'category': 'medicine', 'sha...        Rosbash
# 912  940  [{'year': '2017', 'category': 'medicine', 'sha...          Young
# 913  941  [{'year': '2017', 'category': 'physics', 'shar...          Weiss
# 914  942  [{'year': '2017', 'category': 'physics', 'shar...         Barish
# 915  943  [{'year': '2017', 'category': 'physics', 'shar...         Thorne
# 916  944  [{'year': '2017', 'category': 'chemistry', 'sh...       Dubochet
# 917  945  [{'year': '2017', 'category': 'chemistry', 'sh...          Frank
# 918  946  [{'year': '2017', 'category': 'chemistry', 'sh...      Henderson
# 919  947  [{'year': '2017', 'category': 'literature', 's...       Ishiguro
# 92    95  [{'year': '1972', 'category': 'physics', 'shar...         Cooper
# 920  948  [{'year': '2017', 'category': 'peace', 'share'...            NaN
# 921  949  [{'year': '2017', 'category': 'economics', 'sh...         Thaler
# 93    96  [{'year': '1972', 'category': 'physics', 'shar...     Schrieffer
# 94    97  [{'year': '1973', 'category': 'physics', 'shar...          Esaki
# 95    98  [{'year': '1973', 'category': 'physics', 'shar...        Giaever
# 96    99  [{'year': '1973', 'category': 'physics', 'shar...      Josephson
# 97   100  [{'year': '1974', 'category': 'physics', 'shar...           Ryle
# 98   101  [{'year': '1974', 'category': 'physics', 'shar...         Hewish
# 99   102  [{'year': '1975', 'category': 'physics', 'shar...           Bohr
#
# [922 rows x 13 columns]

# %%
print("The number of countries represented is: %s" %df_L.groupby("bornCountryCode")["bornCountryCode"].count().count())
# counts the number of countries by checking the "bornCountryCode" column
# Out:
# The number of countries represented is: 76

# %%
df_CC = df_L.groupby("bornCountryCode")["bornCountryCode"].count()
# dataframe of the number of countries by checking the "bornCountryCode" column

plot = df_CC.sort_values(ascending = False)[:21].plot(kind = "bar", figsize=(20,10), grid = True, title="Top20")
plot.set_xlabel("Year")
plot.set_ylabel("Population Change")
# plots top 20 countries and labels axes
# Out:
# Text(0,0.5,'Population Change')

# %%
import pandas as pd
import json
# import libraries

"""
df_prize = df_L['prizes']
years = list()

for i in range(0, len(df_prize)):
    print(df_prize[i][0]['year'])

print(df_prize[0][0])
print(df_prize[0][0]['year'])
type(df_prize[0][0]['year'])
"""
laureate_json = json.load(open("nobelprice-laureate.json"))
# loads the json file

laureate_df = pd.DataFrame(laureate_json['laureates'])
# creates dataframe from "laureates" column

prize_df = pd.DataFrame([rec['prizes'][0] for rec in laureate_json['laureates']])
# dataframe of years of prizes grabbed from the "prizes" column of the "laureates" column form the json file

laureate_year_df = pd.concat([laureate_df, prize_df], axis = 1)
# creates new dataframe with the year of the prize added to the original dataframe

year = laureate_year_df.groupby(["year"]).count()
# dataframe of the unique counts of prizes given per year

year.iloc[:,1].plot(kind = "bar", figsize=(20,10), grid = True, title="The Changes of Number of Lauretes' Birth Countries")
plot.set_xlabel("Year")
plot.set_ylabel("Number of Births")
# plots and labels axes
# Out:
# Text(17.2,0.5,'Number of Births')
